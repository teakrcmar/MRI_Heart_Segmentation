# %%
import os
import nibabel as nib
import numpy as np
import random
from tensorflow.keras.utils import to_categorical
# Out:
# 2023-05-17 22:23:55.191330: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.10.1

# %%
image_dir = '/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/mr_train/resized_images2'
label_dir = '/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/mr_train/resized_labels2'

output_shape = (128,128,128)
class_num = 8

image_ids = [f.split('_')[2].split('.')[0] for f in os.listdir(image_dir)]
label_ids = [f.split('_')[2].split('.')[0] for f in os.listdir(label_dir)]

# %%
def get_image_data(image_paths):
    images = []
    for path in image_paths:
        image = nib.load(path)
        image_data = image.get_fdata()
        images.append(image_data)
    return images


def get_label_data(label_path):
    labels = []
    for path in label_path:
        label = nib.load(path)
        label_data = label.get_fdata()
        labels.append(label_data)
    return labels


def data_generator(image_paths, label_paths, batch_size):

    while True:
        for i in range(0, len(image_paths), batch_size):
            batch_image_paths = image_paths[i:i+batch_size]
            batch_label_paths = label_paths[i:i+batch_size]

            batch_images = get_image_data(batch_image_paths)
            batch_labels = get_label_data(batch_label_paths)
                
            batch_images = np.array(batch_images)
            batch_labels = np.array(batch_labels)
            
            yield batch_images, batch_labels

# %%
image_ids = [f.split('_')[2].split('.')[0] for f in os.listdir(image_dir)]
label_ids = [f.split('_')[2].split('.')[0] for f in os.listdir(label_dir)]

np.random.seed(123)
num_epochs = 50
batch_size = 1
val_split = 0.2

for epoch in range(num_epochs):
    np.random.shuffle(image_ids)

    from sklearn.model_selection import train_test_split
    train_ids, val_ids = train_test_split(image_ids, test_size=0.2, random_state=123)

    train_image_paths = [os.path.join(image_dir, f'resized_image_{image_id}.nii') for image_id in train_ids]
    train_label_paths = [os.path.join(label_dir, f'resized_label_{image_id}.nii') for image_id in train_ids]
    val_image_paths = [os.path.join(image_dir, f'resized_image_{image_id}.nii') for image_id in val_ids]
    val_label_paths = [os.path.join(label_dir, f'resized_label_{image_id}.nii') for image_id in val_ids]

    train_steps = len(train_image_paths) // batch_size
    val_steps = len(val_image_paths) // batch_size

    train_generator = data_generator(train_image_paths, train_label_paths, batch_size)
    val_generator = data_generator(val_image_paths, val_label_paths, batch_size)

# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Conv3D, MaxPooling3D, UpSampling3D, Concatenate, Dropout, BatchNormalization, Cropping3D
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv3DTranspose

# %%
def unet(input_size=(128, 128, 128, 1, 2), binary_model = False):
    inputs = Input((input_size[0], input_size[1], input_size[2], input_size[3]))

    # Downsample path
    conv1 = Conv3D(32, 3, activation='relu', padding='same')(inputs)
    conv1 = BatchNormalization()(conv1)
    conv1 = Conv3D(32, 3, activation='relu', padding='same')(conv1)
    conv1 = BatchNormalization()(conv1)
    pool1 = MaxPooling3D(pool_size=(2, 2, 2))(conv1)

    conv2 = Conv3D(64, 3, activation='relu', padding='same')(pool1)
    conv2 = BatchNormalization()(conv2)
    conv2 = Conv3D(64, 3, activation='relu', padding='same')(conv2)
    conv2 = BatchNormalization()(conv2)
    pool2 = MaxPooling3D(pool_size=(2, 2, 2))(conv2)

    conv3 = Conv3D(128, 3, activation='relu', padding='same')(pool2)
    conv3 = BatchNormalization()(conv3)
    conv3 = Conv3D(128, 3, activation='relu', padding='same')(conv3)
    conv3 = BatchNormalization()(conv3)
    pool3 = MaxPooling3D(pool_size=(2, 2, 2))(conv3)

    conv4 = Conv3D(256, 3, activation='relu', padding='same')(pool3)
    conv4 = BatchNormalization()(conv4)
    conv4 = Conv3D(256, 3, activation='relu', padding='same')(conv4)
    conv4 = BatchNormalization()(conv4)
    pool4 = MaxPooling3D(pool_size=(2, 2, 2))(conv4)

    conv5 = Conv3D(512, 3, activation='relu', padding='same')(pool4)
    conv5 = BatchNormalization()(conv5)
    conv5 = Conv3D(512, 3, activation='relu', padding='same')(conv5)
    conv5 = BatchNormalization()(conv5)
    drop5 = Dropout(0.3)(conv5)
    pool5 = MaxPooling3D(pool_size=(2, 2, 2))(drop5)

    # Bottleneck
    conv6 = Conv3D(1024, 3, activation='relu', padding='same')(pool5)
    conv6 = BatchNormalization()(conv6)
    conv6 = Conv3D(1024, 3, activation='relu', padding='same')(conv6)
    conv6 = BatchNormalization()(conv6)
    drop6 = Dropout(0.3)(conv6)

    #Decoder
    up7 = Conv3DTranspose(512, 2, strides=(2, 2, 2), padding='same')(drop6)
    merge7 = Concatenate(axis=4)([up7, drop5])
    conv7 = Conv3D(512, 3, activation='relu', padding='same')(merge7)
    conv7 = BatchNormalization()(conv7)
    conv7 = Conv3D(512, 3, activation='relu', padding='same')(conv7)
    conv7 = BatchNormalization()(conv7)

    up8 = Conv3DTranspose(256, 2, strides=(2, 2, 2), activation='relu', padding='same')(conv7)
    merge8 = Concatenate(axis=4)([conv4, up8])
    conv8 = Conv3D(256, 3, activation='relu', padding='same')(merge8)
    conv8 = BatchNormalization()(conv8)
    conv8 = Conv3D(256, 3, activation='relu', padding='same')(conv8)
    conv8 = BatchNormalization()(conv8)

    up9 = Conv3DTranspose(128, 2, strides=(2, 2, 2), activation='relu', padding='same')(UpSampling3D(size=(1, 1, 1))(conv8))
    merge9 = Concatenate(axis=4)([conv3, up9])
    conv9 = Conv3D(128, 3, activation='relu', padding='same')(merge9)
    conv9 = BatchNormalization()(conv9)
    conv9 = Conv3D(128, 3, activation='relu', padding='same')(conv9)
    conv9 = BatchNormalization()(conv9)

    up10 = Conv3DTranspose(64, 2, activation='relu', padding='same')(UpSampling3D(size=(2, 2, 2))(conv9))
    merge10 = Concatenate(axis=4)([conv2, up10])
    conv10 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(merge10)
    conv10 = BatchNormalization()(conv10)
    conv10 = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(conv10)
    conv10 = BatchNormalization()(conv10)

    up11 = Conv3DTranspose(32, 2, activation='relu', padding='same')(UpSampling3D(size=(2, 2, 2))(conv10))
    merge11 = Concatenate(axis=4)([conv1, up11])
    conv11 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(merge11)
    conv11 = BatchNormalization()(conv11)
    conv11 = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(conv11)
    conv11 = BatchNormalization()(conv11)

    if binary_model:
        outputs = Conv3D(1, (1, 1, 1), activation="sigmoid")(conv11)
    else:
      outputs = Conv3D(8, (1, 1, 1), activation="softmax")(conv11)

    model = Model(inputs, outputs)
    return model

# %%
from sklearn.metrics import f1_score

class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = tf.keras.metrics.Precision()
        self.recall = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)

    def result(self):
        precision = self.precision.result()
        recall = self.recall.result()

        return 2.0 * ((precision * recall) / (precision + recall + tf.keras.backend.epsilon()))

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()

# %%
batch_size = 1
train_steps = len(train_image_paths) // batch_size
val_steps = len(val_image_paths) // batch_size

train_data = data_generator(train_image_paths, train_label_paths, batch_size)
val_data = data_generator(val_image_paths, val_label_paths, batch_size)

input_shape = (128, 128, 128, 1)

model = unet(input_shape)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[tf.keras.metrics.CategoricalAccuracy(),
                       tf.keras.metrics.MeanIoU(num_classes=2),
                       tf.keras.metrics.Precision(),
                       tf.keras.metrics.Recall(),
                       F1Score()])

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 128, 128, 12 0
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 128, 128, 128 896         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 128, 128, 128 128         conv3d_16[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 128, 128, 128 27680       batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 128, 128, 128 128         conv3d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_5 (MaxPooling3D)  (None, 64, 64, 64, 3 0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 64, 64, 64, 6 55360       max_pooling3d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 64, 64, 64, 6 256         conv3d_18[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 64, 64, 64, 6 110656      batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 64, 64, 64, 6 256         conv3d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_6 (MaxPooling3D)  (None, 32, 32, 32, 6 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 32, 32, 32, 1 221312      max_pooling3d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 32, 32, 32, 1 512         conv3d_20[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 32, 32, 32, 1 442496      batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 32, 32, 32, 1 512         conv3d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_7 (MaxPooling3D)  (None, 16, 16, 16, 1 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 16, 16, 16, 2 884992      max_pooling3d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 16, 16, 16, 2 1024        conv3d_22[0][0]
# __________________________________________________________________________________________________
# conv3d_23 (Conv3D)              (None, 16, 16, 16, 2 1769728     batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# batch_normalization_23 (BatchNo (None, 16, 16, 16, 2 1024        conv3d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_8 (MaxPooling3D)  (None, 8, 8, 8, 256) 0           batch_normalization_23[0][0]
# __________________________________________________________________________________________________
# conv3d_24 (Conv3D)              (None, 8, 8, 8, 512) 3539456     max_pooling3d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_24 (BatchNo (None, 8, 8, 8, 512) 2048        conv3d_24[0][0]
# __________________________________________________________________________________________________
# conv3d_25 (Conv3D)              (None, 8, 8, 8, 512) 7078400     batch_normalization_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_25 (BatchNo (None, 8, 8, 8, 512) 2048        conv3d_25[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 8, 8, 8, 512) 0           batch_normalization_25[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_9 (MaxPooling3D)  (None, 4, 4, 4, 512) 0           dropout_2[0][0]
# __________________________________________________________________________________________________
# conv3d_26 (Conv3D)              (None, 4, 4, 4, 1024 14156800    max_pooling3d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 4, 4, 4, 1024 4096        conv3d_26[0][0]
# __________________________________________________________________________________________________
# conv3d_27 (Conv3D)              (None, 4, 4, 4, 1024 28312576    batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 4, 4, 4, 1024 4096        conv3d_27[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 4, 4, 4, 1024 0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_3 (Conv3DTrans (None, 8, 8, 8, 512) 4194816     dropout_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 8, 8, 8, 1024 0           conv3d_transpose_3[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# conv3d_28 (Conv3D)              (None, 8, 8, 8, 512) 14156288    concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 8, 8, 8, 512) 2048        conv3d_28[0][0]
# __________________________________________________________________________________________________
# conv3d_29 (Conv3D)              (None, 8, 8, 8, 512) 7078400     batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 8, 8, 8, 512) 2048        conv3d_29[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_4 (Conv3DTrans (None, 16, 16, 16, 2 1048832     batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 16, 16, 16, 5 0           batch_normalization_23[0][0]
#                                                                  conv3d_transpose_4[0][0]
# __________________________________________________________________________________________________
# conv3d_30 (Conv3D)              (None, 16, 16, 16, 2 3539200     concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 16, 16, 16, 2 1024        conv3d_30[0][0]
# __________________________________________________________________________________________________
# conv3d_31 (Conv3D)              (None, 16, 16, 16, 2 1769728     batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 16, 16, 16, 2 1024        conv3d_31[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_1 (UpSampling3D)  (None, 16, 16, 16, 2 0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_5 (Conv3DTrans (None, 32, 32, 32, 1 262272      up_sampling3d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 32, 2 0           batch_normalization_21[0][0]
#                                                                  conv3d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv3d_32 (Conv3D)              (None, 32, 32, 32, 1 884864      concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 32, 32, 1 512         conv3d_32[0][0]
# __________________________________________________________________________________________________
# conv3d_33 (Conv3D)              (None, 32, 32, 32, 1 442496      batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 32, 32, 32, 1 512         conv3d_33[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_2 (UpSampling3D)  (None, 64, 64, 64, 1 0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_6 (Conv3DTrans (None, 64, 64, 64, 6 65600       up_sampling3d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 64, 64, 64, 1 0           batch_normalization_19[0][0]
#                                                                  conv3d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv3d_34 (Conv3D)              (None, 64, 64, 64, 6 221248      concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 64, 64, 64, 6 256         conv3d_34[0][0]
# __________________________________________________________________________________________________
# conv3d_35 (Conv3D)              (None, 64, 64, 64, 6 110656      batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 64, 64, 64, 6 256         conv3d_35[0][0]
# __________________________________________________________________________________________________
# up_sampling3d_3 (UpSampling3D)  (None, 128, 128, 128 0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# conv3d_transpose_7 (Conv3DTrans (None, 128, 128, 128 16416       up_sampling3d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 128, 128, 128 0           batch_normalization_17[0][0]
#                                                                  conv3d_transpose_7[0][0]
# __________________________________________________________________________________________________
# conv3d_36 (Conv3D)              (None, 128, 128, 128 55328       concatenate_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 128, 128, 128 128         conv3d_36[0][0]
# __________________________________________________________________________________________________
# conv3d_37 (Conv3D)              (None, 128, 128, 128 27680       batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 128, 128, 128 128         conv3d_37[0][0]
# __________________________________________________________________________________________________
# conv3d_38 (Conv3D)              (None, 128, 128, 128 264         batch_normalization_37[0][0]
# ==================================================================================================
# Total params: 90,498,504
# Trainable params: 90,486,472
# Non-trainable params: 12,032
# __________________________________________________________________________________________________

# %%
for X, y in train_data:
    print("Train data shape:", X.shape)
    print("Train labels shape:", y.shape)
    break  

for X, y in val_data:
    print("Validation data shape:", X.shape)
    print("Validation labels shape:", y.shape)
    break  

print("Expected input shape of the model:", model.output_shape)
# Out:
# Train data shape: (1, 128, 128, 128, 1)
# Train labels shape: (1, 128, 128, 128, 8)
# Validation data shape: (1, 128, 128, 128, 1)
# Validation labels shape: (1, 128, 128, 128, 8)
# Expected input shape of the model: (None, 128, 128, 128, 8)

# %%
history = model.fit(
    train_data,
    steps_per_epoch=train_steps,
    epochs=30,
    validation_data=val_data,
    validation_steps=val_steps
)
# Out:
# Epoch 1/30
# 14/14 [==============================] - 15s 1s/step - loss: 0.0441 - categorical_accuracy: 0.9918 - mean_io_u: 0.4375 - precision: 0.9947 - recall: 0.9894 - f1_score: 0.9920 - val_loss: 0.1608 - val_categorical_accuracy: 0.9723 - val_mean_io_u: 0.4375 - val_precision: 0.9749 - val_recall: 0.9722 - val_f1_score: 0.9736
# Epoch 2/30
# 14/14 [==============================] - 15s 1s/step - loss: 0.0425 - categorical_accuracy: 0.9922 - mean_io_u: 0.4375 - precision: 0.9946 - recall: 0.9901 - f1_score: 0.9924 - val_loss: 0.1256 - val_categorical_accuracy: 0.9767 - val_mean_io_u: 0.4375 - val_precision: 0.9786 - val_recall: 0.9760 - val_f1_score: 0.9773
# Epoch 3/30
# 14/14 [==============================] - 15s 1s/step - loss: 0.0414 - categorical_accuracy: 0.9920 - mean_io_u: 0.4375 - precision: 0.9944 - recall: 0.9899 - f1_score: 0.9922 - val_loss: 0.1081 - val_categorical_accuracy: 0.9771 - val_mean_io_u: 0.4375 - val_precision: 0.9809 - val_recall: 0.9761 - val_f1_score: 0.9785
# Epoch 4/30
# 14/14 [==============================] - 15s 1s/step - loss: 0.0385 - categorical_accuracy: 0.9926 - mean_io_u: 0.4375 - precision: 0.9948 - recall: 0.9906 - f1_score: 0.9927 - val_loss: 0.1097 - val_categorical_accuracy: 0.9781 - val_mean_io_u: 0.4375 - val_precision: 0.9841 - val_recall: 0.9764 - val_f1_score: 0.9802
# Epoch 5/30
# 14/14 [==============================] - 15s 1s/step - loss: 0.0364 - categorical_accuracy: 0.9929 - mean_io_u: 0.4375 - precision: 0.9950 - recall: 0.9910 - f1_score: 0.9930 - val_loss: 0.1125 - val_categorical_accuracy: 0.9796 - val_mean_io_u: 0.4375 - val_precision: 0.9829 - val_recall: 0.9785 - val_f1_score: 0.9807
# Epoch 6/30
# 14/14 [==============================] - 15s 1s/step - loss: 0.0339 - categorical_accuracy: 0.9935 - mean_io_u: 0.4375 - precision: 0.9954 - recall: 0.9918 - f1_score: 0.9936 - val_loss: 0.1150 - val_categorical_accuracy: 0.9795 - val_mean_io_u: 0.4375 - val_precision: 0.9820 - val_recall: 0.9788 - val_f1_score: 0.9804
# Epoch 7/30
# 14/14 [==============================] - 15s 1s/step - loss: 0.0312 - categorical_accuracy: 0.9940 - mean_io_u: 0.4375 - precision: 0.9959 - recall: 0.9924 - f1_score: 0.9941 - val_loss: 0.1102 - val_categorical_accuracy: 0.9784 - val_mean_io_u: 0.4375 - val_precision: 0.9810 - val_recall: 0.9776 - val_f1_score: 0.9793
# Epoch 8/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0300 - categorical_accuracy: 0.9940 - mean_io_u: 0.4375 - precision: 0.9958 - recall: 0.9926 - f1_score: 0.9942 - val_loss: 0.1288 - val_categorical_accuracy: 0.9762 - val_mean_io_u: 0.4375 - val_precision: 0.9787 - val_recall: 0.9755 - val_f1_score: 0.9771
# Epoch 9/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0288 - categorical_accuracy: 0.9942 - mean_io_u: 0.4375 - precision: 0.9958 - recall: 0.9929 - f1_score: 0.9943 - val_loss: 0.1427 - val_categorical_accuracy: 0.9754 - val_mean_io_u: 0.4375 - val_precision: 0.9773 - val_recall: 0.9748 - val_f1_score: 0.9760
# Epoch 10/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0278 - categorical_accuracy: 0.9943 - mean_io_u: 0.4375 - precision: 0.9959 - recall: 0.9931 - f1_score: 0.9945 - val_loss: 0.1442 - val_categorical_accuracy: 0.9746 - val_mean_io_u: 0.4375 - val_precision: 0.9764 - val_recall: 0.9741 - val_f1_score: 0.9753
# Epoch 11/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0272 - categorical_accuracy: 0.9944 - mean_io_u: 0.4375 - precision: 0.9958 - recall: 0.9932 - f1_score: 0.9945 - val_loss: 0.1365 - val_categorical_accuracy: 0.9748 - val_mean_io_u: 0.4375 - val_precision: 0.9770 - val_recall: 0.9742 - val_f1_score: 0.9756
# Epoch 12/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0273 - categorical_accuracy: 0.9943 - mean_io_u: 0.4375 - precision: 0.9958 - recall: 0.9931 - f1_score: 0.9944 - val_loss: 0.1252 - val_categorical_accuracy: 0.9768 - val_mean_io_u: 0.4375 - val_precision: 0.9794 - val_recall: 0.9762 - val_f1_score: 0.9778
# Epoch 13/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0281 - categorical_accuracy: 0.9938 - mean_io_u: 0.4375 - precision: 0.9954 - recall: 0.9925 - f1_score: 0.9939 - val_loss: 0.1246 - val_categorical_accuracy: 0.9781 - val_mean_io_u: 0.4375 - val_precision: 0.9799 - val_recall: 0.9775 - val_f1_score: 0.9787
# Epoch 14/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0281 - categorical_accuracy: 0.9936 - mean_io_u: 0.4375 - precision: 0.9954 - recall: 0.9922 - f1_score: 0.9938 - val_loss: 0.1424 - val_categorical_accuracy: 0.9744 - val_mean_io_u: 0.4375 - val_precision: 0.9767 - val_recall: 0.9739 - val_f1_score: 0.9753
# Epoch 15/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0263 - categorical_accuracy: 0.9942 - mean_io_u: 0.4375 - precision: 0.9958 - recall: 0.9928 - f1_score: 0.9943 - val_loss: 0.1220 - val_categorical_accuracy: 0.9786 - val_mean_io_u: 0.4375 - val_precision: 0.9800 - val_recall: 0.9782 - val_f1_score: 0.9791
# Epoch 16/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0254 - categorical_accuracy: 0.9942 - mean_io_u: 0.4375 - precision: 0.9957 - recall: 0.9929 - f1_score: 0.9943 - val_loss: 0.1382 - val_categorical_accuracy: 0.9743 - val_mean_io_u: 0.4375 - val_precision: 0.9765 - val_recall: 0.9737 - val_f1_score: 0.9751
# Epoch 17/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0239 - categorical_accuracy: 0.9947 - mean_io_u: 0.4375 - precision: 0.9960 - recall: 0.9935 - f1_score: 0.9947 - val_loss: 0.1268 - val_categorical_accuracy: 0.9774 - val_mean_io_u: 0.4375 - val_precision: 0.9788 - val_recall: 0.9769 - val_f1_score: 0.9779
# Epoch 18/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0238 - categorical_accuracy: 0.9946 - mean_io_u: 0.4375 - precision: 0.9960 - recall: 0.9935 - f1_score: 0.9947 - val_loss: 0.1270 - val_categorical_accuracy: 0.9767 - val_mean_io_u: 0.4375 - val_precision: 0.9788 - val_recall: 0.9761 - val_f1_score: 0.9775
# Epoch 19/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0238 - categorical_accuracy: 0.9945 - mean_io_u: 0.4375 - precision: 0.9958 - recall: 0.9933 - f1_score: 0.9946 - val_loss: 0.1071 - val_categorical_accuracy: 0.9788 - val_mean_io_u: 0.4375 - val_precision: 0.9809 - val_recall: 0.9781 - val_f1_score: 0.9795
# Epoch 20/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0228 - categorical_accuracy: 0.9947 - mean_io_u: 0.4375 - precision: 0.9959 - recall: 0.9938 - f1_score: 0.9948 - val_loss: 0.1133 - val_categorical_accuracy: 0.9780 - val_mean_io_u: 0.4375 - val_precision: 0.9812 - val_recall: 0.9772 - val_f1_score: 0.9792
# Epoch 21/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0232 - categorical_accuracy: 0.9944 - mean_io_u: 0.4375 - precision: 0.9957 - recall: 0.9933 - f1_score: 0.9945 - val_loss: 0.1217 - val_categorical_accuracy: 0.9788 - val_mean_io_u: 0.4375 - val_precision: 0.9802 - val_recall: 0.9783 - val_f1_score: 0.9793
# Epoch 22/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0213 - categorical_accuracy: 0.9949 - mean_io_u: 0.4375 - precision: 0.9961 - recall: 0.9939 - f1_score: 0.9950 - val_loss: 0.1461 - val_categorical_accuracy: 0.9748 - val_mean_io_u: 0.4375 - val_precision: 0.9764 - val_recall: 0.9744 - val_f1_score: 0.9754
# Epoch 23/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0202 - categorical_accuracy: 0.9951 - mean_io_u: 0.4375 - precision: 0.9962 - recall: 0.9942 - f1_score: 0.9952 - val_loss: 0.1413 - val_categorical_accuracy: 0.9760 - val_mean_io_u: 0.4375 - val_precision: 0.9772 - val_recall: 0.9756 - val_f1_score: 0.9764
# Epoch 24/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0195 - categorical_accuracy: 0.9953 - mean_io_u: 0.4375 - precision: 0.9964 - recall: 0.9944 - f1_score: 0.9954 - val_loss: 0.1273 - val_categorical_accuracy: 0.9772 - val_mean_io_u: 0.4375 - val_precision: 0.9791 - val_recall: 0.9766 - val_f1_score: 0.9778
# Epoch 25/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0194 - categorical_accuracy: 0.9953 - mean_io_u: 0.4375 - precision: 0.9963 - recall: 0.9945 - f1_score: 0.9954 - val_loss: 0.1264 - val_categorical_accuracy: 0.9779 - val_mean_io_u: 0.4375 - val_precision: 0.9796 - val_recall: 0.9772 - val_f1_score: 0.9784
# Epoch 26/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0186 - categorical_accuracy: 0.9954 - mean_io_u: 0.4375 - precision: 0.9964 - recall: 0.9946 - f1_score: 0.9955 - val_loss: 0.1218 - val_categorical_accuracy: 0.9780 - val_mean_io_u: 0.4375 - val_precision: 0.9796 - val_recall: 0.9774 - val_f1_score: 0.9785
# Epoch 27/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0178 - categorical_accuracy: 0.9957 - mean_io_u: 0.4375 - precision: 0.9966 - recall: 0.9948 - f1_score: 0.9957 - val_loss: 0.1201 - val_categorical_accuracy: 0.9801 - val_mean_io_u: 0.4375 - val_precision: 0.9812 - val_recall: 0.9797 - val_f1_score: 0.9804
# Epoch 28/30
# 14/14 [==============================] - 14s 1s/step - loss: 0.0174 - categorical_accuracy: 0.9957 - mean_io_u: 0.4375 - precision: 0.9965 - recall: 0.9950 - f1_score: 0.9958 - val_loss: 0.1272 - val_categorical_accuracy: 0.9776 - val_mean_io_u: 0.4375 - val_precision: 0.9791 - val_recall: 0.9771 - val_f1_score: 0.9781
# Epoch 29/30
# 14/14 [==============================] - 15s 1s/step - loss: 0.0165 - categorical_accuracy: 0.9959 - mean_io_u: 0.4375 - precision: 0.9968 - recall: 0.9952 - f1_score: 0.9960 - val_loss: 0.1122 - val_categorical_accuracy: 0.9795 - val_mean_io_u: 0.4375 - val_precision: 0.9811 - val_recall: 0.9788 - val_f1_score: 0.9800
# Epoch 30/30
# 14/14 [==============================] - 15s 1s/step - loss: 0.0164 - categorical_accuracy: 0.9959 - mean_io_u: 0.4375 - precision: 0.9967 - recall: 0.9952 - f1_score: 0.9960 - val_loss: 0.1334 - val_categorical_accuracy: 0.9780 - val_mean_io_u: 0.4375 - val_precision: 0.9789 - val_recall: 0.9776 - val_f1_score: 0.9783

# %%
model.save('/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/128_v3_model.h5')

# %%
import matplotlib.pyplot as plt

train_losses = history.history['loss']
val_losses = history.history['val_loss']
num_epochs = range(1, len(train_losses) + 1)  

plt.plot(num_epochs, train_losses, label='Training loss')
plt.plot(num_epochs, val_losses, label='Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
train_iou = history.history['mean_io_u']
val_iou = history.history['val_mean_io_u']
num_epochs = range(1, len(train_iou) + 1)  

plt.plot(num_epochs, train_iou, label='Training IOU')
plt.plot(num_epochs, val_iou, label='Validation IOU')
plt.xlabel('Epochs')
plt.ylabel('IOU')
plt.title('Training and Validation IOU')
plt.legend()
plt.show()

# %%
train_f1 = history.history['f1_score']
val_f1 = history.history['val_f1_score']
num_epochs = range(1, len(train_f1) + 1)  

plt.plot(num_epochs, train_f1, label='Training F1 Score')
plt.plot(num_epochs, val_f1, label='Validation F1 Score')
plt.xlabel('Epochs')
plt.ylabel('F1 Score')
plt.title('Training and Validation F1 Score')
plt.legend()
plt.show()

# %%
import scipy.ndimage

test_image = '/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/mr_train/resized_image_1019.nii'
test_image = nib.load(test_image).get_fdata()
resized_test_image = np.expand_dims(test_image, axis=0)


predicted_mask = model.predict(resized_test_image)

# %%
predicted_mask = predicted_mask.astype(np.float64)

# %%
ground_truth_mask = '/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/mr_train/resized_label_1019.nii'
ground_truth_mask = nib.load(ground_truth_mask).get_fdata()


dice = 2 * np.sum(predicted_mask * ground_truth_mask) / (np.sum(predicted_mask) + np.sum(ground_truth_mask))
intersection = np.sum(predicted_mask * ground_truth_mask)
union = np.sum(predicted_mask) + np.sum(ground_truth_mask) - intersection
jaccard = intersection / union

print("Dice coefficient:", dice)
print("Jaccard similarity:", jaccard)
# Out:
# Dice coefficient: 0.9890663814445878
# Jaccard similarity: 0.9783692650937142

# %%
print(predicted_mask.shape)
# Out:
# (1, 128, 128, 128, 8)

# %%
# Select the first channel of the predicted mask
channel = 1
slice_2d = predicted_mask[0, :, :, int(predicted_mask.shape[3] / 2), channel]

# Display the 2D slice
plt.imshow(slice_2d, cmap='gray')

# %%
print(ground_truth_mask.shape)
# Out:
# (128, 128, 128, 8)

# %%
channel = 1
ground_truth_2d = ground_truth_mask[:, :, 64, channel]

f, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].imshow(test_image[:, :, 64], cmap='gray')
ax[0].set_title('Original Image')
ax[1].imshow(slice_2d, cmap='gray')
ax[1].set_title('Predicted Mask')
ax[2].imshow(ground_truth_2d, cmap='gray')
ax[2].set_title('Ground Truth Mask')

plt.show()

# %%
test_image2 = '/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/mr_train/resized_image_1020.nii'
test_image2 = nib.load(test_image2).get_fdata()
print(test_image2.shape)
resized_test_image2 = np.expand_dims(test_image2, axis=0)

predicted_mask2 = model.predict(resized_test_image2)
# Out:
# (128, 128, 128, 1)

# %%
channel = 1
slice2_2d = predicted_mask2[0, :, :, 64, channel]

plt.imshow(slice2_2d, cmap='gray')

# %%
ground_truth_mask2 = '/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/mr_train/resized_label_1020.nii'
ground_truth_mask2 = nib.load(ground_truth_mask2).get_fdata()


dice = 2 * np.sum(predicted_mask2 * ground_truth_mask2) / (np.sum(predicted_mask2) + np.sum(ground_truth_mask2))

intersection = np.sum(predicted_mask2 * ground_truth_mask2)
union = np.sum(predicted_mask2) + np.sum(ground_truth_mask2) - intersection
jaccard = intersection / union

print("Dice coefficient:", dice)
print("Jaccard similarity:", jaccard)
# Out:
# Dice coefficient: 0.9786352533069259
# Jaccard similarity: 0.9581643154176842

# %%
channel = 1
ground_truth2_2d = ground_truth_mask2[:, :, 64, channel]

f, ax = plt.subplots(1, 3, figsize=(15, 5))

ax[0].imshow(test_image2[:, :, 64], cmap='gray')
ax[0].set_title('Original Image')
ax[1].imshow(slice2_2d, cmap='gray')
ax[1].set_title('Predicted Mask')
ax[2].imshow(ground_truth2_2d, cmap='gray')
ax[2].set_title('Ground Truth Mask')

plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

def dsc_calc(y_true, y_pred):
    y_true = y_true.reshape(-1)
    y_pred = y_pred.reshape(-1)
    intersection = np.sum(y_true * y_pred)
    return (2 * intersection) / (np.sum(y_true) + np.sum(y_pred))

def dsc_by_label(y_true, y_pred, label_index):
    return dsc_calc(y_true[:,:,:,label_index], y_pred[:,:,:,label_index])

def label_encoding(label):
    label_encoder = LabelEncoder()
    shape = label.shape
    label = label.reshape(-1)
    label = label_encoder.fit_transform(label)
    label = to_categorical(label, 8)
    label = label.reshape(shape + (8,))
    
    return label

def evaluate(y_true1, y_true2, y_pred1, y_pred2):
    print('Valid 1')
    dsc = dsc_calc(y_true1, y_pred1)
    print('DSC: {0:.4f}'.format(dsc))

    dsc_mean1 = list()
    for i in range(8):
        dsc_i = dsc_by_label(y_true1, y_pred1, i)
        if i!=0:
            dsc_mean1.append(dsc_i)
        print('label_{0:}: {1:.3f}'.format(i, dsc_i))
    print('Average DSC: {0:.3f}'.format(np.mean(dsc_mean1)))

    print('='*50)

    print('Valid 2')
    dsc = dsc_calc(y_true2, y_pred2)
    print('DSC: {0:.4f}'.format(dsc))

    dsc_mean2 = list()
    for i in range(8):
        dsc_i = dsc_by_label(y_true2, y_pred2, i)
        if i!=0:
            dsc_mean2.append(dsc_i)
        print('label_{0:}: {1:.3f}'.format(i, dsc_i))
    print('Average DSC: {0:.3f}'.format(np.mean(dsc_mean2)))
    
    return dsc_mean1, dsc_mean2

# %%
import pandas as pd 

def model_evaluate(metric, valid_images):
    exp = pd.read_hdf('/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/128_v3_model.h5')
    exp_image_1 = nib.load('/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/mr_train/resized_label_1019.nii').get_fdata()
    exp_image_2 = nib.load('/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/mr_train/resized_label_1019.nii').get_fdata()
    print('exp_image_1 label: ',np.unique(exp_image_1))
    print('exp_image_2 label: ',np.unique(exp_image_2))
    print()
    exp_image_1 = label_encoding(exp_image_1)
    exp_image_2 = label_encoding(exp_image_2)
    print('encoding exp_image_1.shape: ',exp_image_1.shape)
    print('encoding exp_image_2.shape: ',exp_image_2.shape)
    print()

    fig, ax = plt.subplots(1,2, figsize=(12,5))
    ax[0].plot(exp['loss'], 'y', label='train loss')
    ax[0].plot(exp['val_loss'], 'r', label='val loss')
    ax[0].set_xlabel('epoch')
    ax[0].set_ylabel('loss')
    ax[0].set_ylim([0,1])
    ax[0].legend(loc='upper right')

    ax[1].plot(exp['{}'.format(metric)], 'b', label='train {} coefficient'.format(metric))
    ax[1].plot(exp['val_{}'.format(metric)], 'g', label='val {} coefficient'.format(metric))
    ax[1].set_xlabel('epoch')
    ax[1].set_ylabel('{}'.format(metric))
    ax[1].set_ylim([0,1])
    ax[1].legend(loc='lower right')

    fig, ax = plt.subplots(2,4, figsize=(20,10))
    for i in range(8):
        ax[i//4,i%4].plot(exp['DSC_{}'.format(i)], 'b', label='train DSC{}'.format(i))
        ax[i//4,i%4].plot(exp['val_DSC_{}'.format(i)], 'r', label='val DSC{}'.format(i))
        ax[i//4,i%4].set_xlabel('epoch')
        ax[i//4,i%4].set_ylabel('Dice Similarity Coefficient')
        ax[i//4,i%4].legend(loc='upper right')
        ax[i//4,i%4].set_ylim([0,1])

    val1_dsc, val2_dsc = evaluate(valid_images[0], valid_images[1], exp_image_1, exp_image_2)
    
    return val1_dsc, val2_dsc

# %%
valid_1 = nib.load('/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/mr_train/resized_label_1019.nii').get_fdata()
valid_2 = nib.load('/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/mr_train/resized_label_1020.nii').get_fdata()
print('valid_1.shape: ',valid_1.shape)
print('valid_2.shape: ',valid_2.shape)
print()
valid_1 = label_encoding(valid_1)
valid_2 = label_encoding(valid_2)
print('encoding valid_1.shape: ',valid_1.shape)
print('encoding valid_2.shape: ',valid_2.shape)
# Out:
# valid_1.shape:  (128, 128, 128, 8)
# valid_2.shape:  (128, 128, 128, 8)
#
# encoding valid_1.shape:  (128, 128, 128, 8, 8)
# encoding valid_2.shape:  (128, 128, 128, 8, 8)

# %%
import tensorflow.keras as keras

model_architecture = keras.models.load_model('/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/128_v3_model.h5')

# Create an instance of the model using the loaded architecture
model = keras.models.Model.from_config(model_architecture.get_config())

# Load the model weights from the saved file
model.load_weights('/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/128_v3_model.h5')
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=[tf.keras.metrics.CategoricalAccuracy(),
                       tf.keras.metrics.MeanIoU(num_classes=2),
                       ])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 3
#       1 import tensorflow.keras as keras
# ----> 3 model_architecture = keras.models.load_model('/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/128_v3_model.h5')
#       5 # Create an instance of the model using the loaded architecture
#       6 model = keras.models.Model.from_config(model_architecture.get_config())
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/keras/saving/save.py:206, in load_model(filepath, custom_objects, compile, options)
#     203 with load_context.load_context(options):
#     204   if (h5py is not None and
#     205       (isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 206     return hdf5_format.load_model_from_hdf5(filepath, custom_objects,
#     207                                             compile)
#     209   filepath = path_to_string(filepath)
#     210   if isinstance(filepath, six.string_types):
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/keras/saving/hdf5_format.py:199, in load_model_from_hdf5(filepath, custom_objects, compile)
#     196 training_config = json_utils.decode(training_config.decode('utf-8'))
#     198 # Compile model.
# --> 199 model.compile(**saving_utils.compile_args_from_training_config(
#     200     training_config, custom_objects))
#     201 saving_utils.try_build_compiled_arguments(model)
#     203 # Set optimizer weights.
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/keras/saving/saving_utils.py:224, in compile_args_from_training_config(training_config, custom_objects)
#     222 metrics_config = training_config.get('metrics', None)
#     223 if metrics_config is not None:
# --> 224   metrics = _deserialize_nested_config(_deserialize_metric, metrics_config)
#     226 # Recover weighted metrics.
#     227 weighted_metrics = None
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/keras/saving/saving_utils.py:266, in _deserialize_nested_config(deserialize_fn, config)
#     261   return {
#     262       k: _deserialize_nested_config(deserialize_fn, v)
#     263       for k, v in config.items()
#     264   }
#     265 elif isinstance(config, (tuple, list)):
# --> 266   return [_deserialize_nested_config(deserialize_fn, obj) for obj in config]
#     268 raise ValueError('Saved configuration not understood.')
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/keras/saving/saving_utils.py:266, in <listcomp>(.0)
#     261   return {
#     262       k: _deserialize_nested_config(deserialize_fn, v)
#     263       for k, v in config.items()
#     264   }
#     265 elif isinstance(config, (tuple, list)):
# --> 266   return [_deserialize_nested_config(deserialize_fn, obj) for obj in config]
#     268 raise ValueError('Saved configuration not understood.')
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/keras/saving/saving_utils.py:266, in _deserialize_nested_config(deserialize_fn, config)
#     261   return {
#     262       k: _deserialize_nested_config(deserialize_fn, v)
#     263       for k, v in config.items()
#     264   }
#     265 elif isinstance(config, (tuple, list)):
# --> 266   return [_deserialize_nested_config(deserialize_fn, obj) for obj in config]
#     268 raise ValueError('Saved configuration not understood.')
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/keras/saving/saving_utils.py:266, in <listcomp>(.0)
#     261   return {
#     262       k: _deserialize_nested_config(deserialize_fn, v)
#     263       for k, v in config.items()
#     264   }
#     265 elif isinstance(config, (tuple, list)):
# --> 266   return [_deserialize_nested_config(deserialize_fn, obj) for obj in config]
#     268 raise ValueError('Saved configuration not understood.')
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/keras/saving/saving_utils.py:259, in _deserialize_nested_config(deserialize_fn, config)
#     257   return None
#     258 if _is_single_object(config):
# --> 259   return deserialize_fn(config)
#     260 elif isinstance(config, dict):
#     261   return {
#     262       k: _deserialize_nested_config(deserialize_fn, v)
#     263       for k, v in config.items()
#     264   }
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/keras/saving/saving_utils.py:289, in _deserialize_metric(metric_config)
#     285 if metric_config in ['accuracy', 'acc', 'crossentropy', 'ce']:
#     286   # Do not deserialize accuracy and cross-entropy strings as we have special
#     287   # case handling for these in compile, based on model output shape.
#     288   return metric_config
# --> 289 return metrics_module.deserialize(metric_config)
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/keras/metrics.py:3446, in deserialize(config, custom_objects)
#    3434 @keras_export('keras.metrics.deserialize')
#    3435 def deserialize(config, custom_objects=None):
#    3436   """Deserializes a serialized metric class/function instance.
#    3437
#    3438   Arguments:
#    (...)
#    3444       A Keras `Metric` instance or a metric function.
#    3445   """
# -> 3446   return deserialize_keras_object(
#    3447       config,
#    3448       module_objects=globals(),
#    3449       custom_objects=custom_objects,
#    3450       printable_module_name='metric function')
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/keras/utils/generic_utils.py:346, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     343 if isinstance(identifier, dict):
#     344   # In this case we are dealing with a Keras config dictionary.
#     345   config = identifier
# --> 346   (cls, cls_config) = class_and_config_for_serialized_keras_object(
#     347       config, module_objects, custom_objects, printable_module_name)
#     349   if hasattr(cls, 'from_config'):
#     350     arg_spec = tf_inspect.getfullargspec(cls.from_config)
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/tensorflow/python/keras/utils/generic_utils.py:296, in class_and_config_for_serialized_keras_object(config, module_objects, custom_objects, printable_module_name)
#     294 cls = get_registered_object(class_name, custom_objects, module_objects)
#     295 if cls is None:
# --> 296   raise ValueError('Unknown ' + printable_module_name + ': ' + class_name)
#     298 cls_config = config['config']
#     299 # Check if `cls_config` is a list. If it is a list, return the class and the
#     300 # associated class configs for recursively deserialization. This case will
#     301 # happen on the old version of sequential model (e.g. `keras_version` ==
#     302 # "2.0.6"), which is serialized in a different structure, for example
#     303 # "{'class_name': 'Sequential',
#     304 #   'config': [{'class_name': 'Embedding', 'config': ...}, {}, ...]}".
#
# ValueError: Unknown metric function: F1Score

# %%
val1_dsc_exp1, val2_dsc_exp1 = model_evaluate('exp1234', 'UNET_3D', 'dice_coefficient', [valid_1, valid_2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 val1_dsc_exp1, val2_dsc_exp1 = model_evaluate('exp1234', 'UNET_3D', 'dice_coefficient', [valid_1, valid_2])
#
# Cell In[71], line 4, in model_evaluate(folder, exp_name, metric, valid_images)
#       3 def model_evaluate(folder,exp_name, metric, valid_images):
# ----> 4     exp = pd.read_hdf('/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/128_v3_model.h5')
#       5     exp_image_1 = nib.load('/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/mr_train/resized_label_1019.nii').get_fdata()
#       6     exp_image_2 = nib.load('/home/teakrcmar/Desktop/3D_Unet_HeartSegmentation/mr_train/resized_label_1019.nii').get_fdata()
#
# File ~/anaconda3/envs/tf_gpu/lib/python3.9/site-packages/pandas/io/pytables.py:425, in read_hdf(path_or_buf, key, mode, errors, where, start, stop, columns, iterator, chunksize, **kwargs)
#     423 groups = store.groups()
#     424 if len(groups) == 0:
# --> 425     raise ValueError(
#     426         "Dataset(s) incompatible with Pandas data types, "
#     427         "not table, or no datasets found in HDF5 file."
#     428     )
#     429 candidate_only_group = groups[0]
#     431 # For the HDF file to have only one dataset, all other groups
#     432 # should then be metadata groups for that candidate group. (This
#     433 # assumes that the groups() method enumerates parent groups
#     434 # before their children.)
#
# ValueError: Dataset(s) incompatible with Pandas data types, not table, or no datasets found in HDF5 file.
